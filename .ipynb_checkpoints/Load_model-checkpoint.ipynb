# %% [markdown]
# ## Different imports and setup

# %%
# Standard import
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/mydrive')
# Out:
# Mounted at /content/mydrive

# %%
# %cd /content/mydrive/MyDrive/Semester_project
# !ls
# Out:
# /content/mydrive/MyDrive/Semester_project
# Basis_functions_1D.ipynb  Data		    Saved_models  Train_model_1D.ipynb
# Create_data_1D.ipynb	  Load_model.ipynb  Tools

# %%
# Machine learning libraries
from tensorflow import keras
import tensorflow as tf

# %%
from Tools import Plot
from Tools import Custom_models

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print('Not working on GPU !')
else:
  print('Found GPU at: {}'.format(device_name))
# Out:
# Not working on GPU !

# %% [markdown]
# ## Load a model

# %%
model_name = 'Saved_models/model_tanh_200_epochs_reg_0_01'
model = keras.models.load_model(model_name)

# %%
model.summary()
# Out:
# Model: "model_1d_regularization"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense1 (Dense)               multiple                  200
# _________________________________________________________________
# dense2 (Dense)               multiple                  9898
# _________________________________________________________________
# dense3 (Dense)               multiple                  99
# =================================================================
# Total params: 10,197
# Trainable params: 10,197
# Non-trainable params: 0
# _________________________________________________________________

# %%
weights1 = model.get_layer(name='dense1').get_weights()
weights2 = model.get_layer(name='dense2').get_weights()
weights3 = model.get_layer(name='dense3').get_weights()

# %%
core1 = weights1[0]
bias1 = weights1[1]
core2 = weights2[0]
bias2 = weights2[1]
core3 = weights3[0]
bias3 = weights3[1]

# %%
print(core2.shape)
# Out:
# (100, 98)

# %%
print(core2[78,:])
# Out:
# [-1.29995099e-03 -4.56860871e-04 -2.68919597e-04  1.01154234e-04
#  -5.54384664e-04 -1.87245512e-03 -6.48034620e-04 -1.29615911e-03
#  -5.35167637e-04  1.10224495e-03 -1.37728290e-03 -1.33815594e-03
#  -1.54607859e-03  1.80186122e-04 -5.32566570e-03  7.14677153e-05
#  -3.56562063e-03  1.21072051e-03 -6.13154669e-04 -4.11635119e-04
#  -1.24940381e-03  7.37401890e-04  3.78268538e-04 -1.66054117e-04
#   2.68305978e-03 -2.85255443e-03  4.22441168e-04 -1.91667583e-04
#   4.62638098e-04  2.86633708e-03 -6.45864056e-04 -1.91679120e-03
#  -4.12031636e-03 -1.53237302e-03 -1.97543856e-03 -3.55860335e-04
#  -2.08581332e-03  3.35215416e-04 -4.01755446e-04  4.93135653e-04
#   5.97443548e-04  1.91599189e-04 -9.50012123e-04 -3.76108481e-04
#   1.15736795e-04  5.89252217e-04  7.01847486e-04  1.74689083e-03
